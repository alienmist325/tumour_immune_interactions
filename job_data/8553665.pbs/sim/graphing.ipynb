# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from graphing import get_sim, get_pops, graph, hist, savefig, fish_tumour, fish_CTL
import numpy as np

# %%
sim = get_sim("../sim_data/sim.pickle")
tumour_cells_pop, CTL_cells_pop = get_pops(sim)
# Out:
# Successfully opened the previous simulation.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload
from graphing import get_sim, get_pops, graph, hist, fish, savefig

# %%
#times = np.linspace(0, 100, sim.final_time_step) # Works on stuff before, if you manually put the end time.
"""
times = np.linspace(0, sim.final_time, sim.final_time_step) # Only works on Config10+



plt.plot(times, tumour_cells_pop, label="Tumour Cells")
plt.plot(times, CTL_cells_pop, label="CTL Cells")
plt.legend()
"""
# Out:
# '\ntimes = np.linspace(0, sim.final_time, sim.final_time_step) # Only works on Config10+\n\n\n\nplt.plot(times, tumour_cells_pop, label="Tumour Cells")\nplt.plot(times, CTL_cells_pop, label="CTL Cells")\nplt.legend()\n'

# %%
graph(sim).show()

# %%
hist(sim).show()

# %%
#sim.history.state_init_type = "detailed"
fish_tumour(sim).show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# g:\Programming\UPythonSource\tumour_immune_interactions\sim\graphing.ipynb Cell 8 line 2
#       <a href='vscode-notebook-cell:/g%3A/Programming/UPythonSource/tumour_immune_interactions/sim/graphing.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> sim.history.state_init_type = "detailed"
# ----> <a href='vscode-notebook-cell:/g%3A/Programming/UPythonSource/tumour_immune_interactions/sim/graphing.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> fish(sim, "CTL").show()
#
# NameError: name 'fish' is not defined

# %%
savefig(sim,fish_tumour)
# Out:
# c:\Users\akesh\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyfish\core.py:200: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 88.5  88.5  78.5  78.5  78.5  78.5  75.5  75.5  85.   85.   81.   81.
#   79.   79.   79.5  79.5  84.   84.   75.5  75.5  90.5  90.5  88.   88.
#   88.   88.   84.   84.   98.   98.   99.5  99.5  83.5  83.5  93.   93.
#   93.   93.   86.   86.   85.   85.   94.5  94.5  85.   85.   75.5  75.5
#   80.   80.   84.5  84.5  85.5  85.5  91.5  91.5  98.   98.   95.   95.
#   90.5  90.5  85.   85.   82.5  82.5 103.  103.   92.   92.   85.5  85.5
#   81.5  81.5  81.5  81.5  97.   97.   89.5  89.5  82.   82.   77.5  77.5
#   87.   87.  102.  102.   72.5  72.5 101.  101.   89.5  89.5  80.5  80.5
#   85.5  85.5  91.   91.   91.   91.   94.5  94.5  86.5  86.5  97.5  97.5
#   92.   92.   98.   98.   93.5  93.5  82.5  82.5 101.5 101.5  85.   85.
# ...
