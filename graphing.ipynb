# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from graphing import get_sim, get_pops

# %%
sim = get_sim("sim_data/sim.pickle")
tumour_cells_pop, CTL_cells_pop = get_pops(sim)
# Out:
# Successfully opened the previous simulation.

# %%
plt.plot(tumour_cells_pop, label="Tumour Cells")
plt.plot(CTL_cells_pop, label="CTL Cells")
plt.legend()
